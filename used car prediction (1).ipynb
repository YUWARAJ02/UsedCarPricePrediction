# %%
#IMPORT PACKAGES
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost.sklearn import XGBRegressor
from sklearn.neural_network import MLPRegressor
from sklearn import metrics

# %% [markdown]
# LOAD DATASET

# %%
data = pd.read_csv('F:/used car prediction/train-data.csv')
test = pd.read_csv('F:/used car prediction/test-data.csv')

# %%
data
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First  26.6 km/kg
# 1                 41000    Diesel       Manual      First  19.67 kmpl
# 2                 46000    Petrol       Manual      First   18.2 kmpl
# 3                 87000    Diesel       Manual      First  20.77 kmpl
# 4                 40670    Diesel    Automatic     Second   15.2 kmpl
# ...                 ...       ...          ...        ...         ...
# 6014              27365    Diesel       Manual      First   28.4 kmpl
# 6015             100000    Diesel       Manual      First   24.4 kmpl
# 6016              55000    Diesel       Manual     Second   14.0 kmpl
# 6017              46000    Petrol       Manual      First   18.9 kmpl
# 6018              47000    Diesel       Manual      First  25.44 kmpl
#
#        Engine      Power  Seats  New_Price  Price
# 0      998 CC  58.16 bhp    5.0        NaN   1.75
# 1     1582 CC  126.2 bhp    5.0        NaN  12.50
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50
# 3     1248 CC  88.76 bhp    7.0        NaN   6.00
# 4     1968 CC  140.8 bhp    5.0        NaN  17.74
# ...       ...        ...    ...        ...    ...
# 6014  1248 CC     74 bhp    5.0  7.88 Lakh   4.75
# 6015  1120 CC     71 bhp    5.0        NaN   4.00
# 6016  2498 CC    112 bhp    8.0        NaN   2.90
# 6017   998 CC   67.1 bhp    5.0        NaN   2.65
# 6018   936 CC   57.6 bhp    5.0        NaN   2.50
#
# [6019 rows x 14 columns]

# %%
test
# Out:
#       Unnamed: 0                                               Name  \
# 0              0                            Maruti Alto K10 LXI CNG
# 1              1                      Maruti Alto 800 2016-2019 LXI
# 2              2          Toyota Innova Crysta Touring Sport 2.4 MT
# 3              3                               Toyota Etios Liva GD
# 4              4                                  Hyundai i20 Magna
# ...          ...                                                ...
# 1229        1229                  Volkswagen Vento Diesel Trendline
# 1230        1230                             Volkswagen Polo GT TSI
# 1231        1231                             Nissan Micra Diesel XV
# 1232        1232                             Volkswagen Polo GT TSI
# 1233        1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...
#
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0          Delhi  2014              40929       CNG       Manual      First
# 1     Coimbatore  2013              54493    Petrol       Manual     Second
# 2         Mumbai  2017              34000    Diesel       Manual      First
# 3      Hyderabad  2012             139000    Diesel       Manual      First
# 4         Mumbai  2014              29000    Petrol       Manual      First
# ...          ...   ...                ...       ...          ...        ...
# 1229   Hyderabad  2011              89411    Diesel       Manual      First
# 1230      Mumbai  2015              59000    Petrol    Automatic      First
# 1231     Kolkata  2012              28000    Diesel       Manual      First
# 1232        Pune  2013              52262    Petrol    Automatic      Third
# 1233       Kochi  2014              72443    Diesel    Automatic      First
#
#           Mileage   Engine      Power  Seats   New_Price
# 0     32.26 km/kg   998 CC   58.2 bhp    4.0         NaN
# 1       24.7 kmpl   796 CC   47.3 bhp    5.0         NaN
# 2      13.68 kmpl  2393 CC  147.8 bhp    7.0  25.27 Lakh
# 3      23.59 kmpl  1364 CC   null bhp    5.0         NaN
# 4       18.5 kmpl  1197 CC  82.85 bhp    5.0         NaN
# ...           ...      ...        ...    ...         ...
# 1229   20.54 kmpl  1598 CC  103.6 bhp    5.0         NaN
# 1230   17.21 kmpl  1197 CC  103.6 bhp    5.0         NaN
# 1231   23.08 kmpl  1461 CC   63.1 bhp    5.0         NaN
# 1232    17.2 kmpl  1197 CC  103.6 bhp    5.0         NaN
# 1233    10.0 kmpl  2148 CC    170 bhp    5.0         NaN
#
# [1234 rows x 13 columns]

# %% [markdown]
# DATA PREPROCESSING

# %%
data = data.drop('New_Price', axis=1)
data = data.drop('Unnamed: 0', axis=1)

test = test.drop('New_Price', axis=1)
test = test.drop('Unnamed: 0', axis=1)

# %%
data
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0          CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1       Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2       Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3       Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4       Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
# ...        ...          ...        ...         ...      ...        ...    ...
# 6014    Diesel       Manual      First   28.4 kmpl  1248 CC     74 bhp    5.0
# 6015    Diesel       Manual      First   24.4 kmpl  1120 CC     71 bhp    5.0
# 6016    Diesel       Manual     Second   14.0 kmpl  2498 CC    112 bhp    8.0
# 6017    Petrol       Manual      First   18.9 kmpl   998 CC   67.1 bhp    5.0
# 6018    Diesel       Manual      First  25.44 kmpl   936 CC   57.6 bhp    5.0
#
#       Price
# 0      1.75
# 1     12.50
# 2      4.50
# 3      6.00
# 4     17.74
# ...     ...
# 6014   4.75
# 6015   4.00
# 6016   2.90
# 6017   2.65
# 6018   2.50
#
# [6019 rows x 12 columns]

# %%
test
# Out:
#                                                    Name    Location  Year  \
# 0                               Maruti Alto K10 LXI CNG       Delhi  2014
# 1                         Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2             Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 3                                  Toyota Etios Liva GD   Hyderabad  2012
# 4                                     Hyundai i20 Magna      Mumbai  2014
# ...                                                 ...         ...   ...
# 1229                  Volkswagen Vento Diesel Trendline   Hyderabad  2011
# 1230                             Volkswagen Polo GT TSI      Mumbai  2015
# 1231                             Nissan Micra Diesel XV     Kolkata  2012
# 1232                             Volkswagen Polo GT TSI        Pune  2013
# 1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage  \
# 0                 40929       CNG       Manual      First  32.26 km/kg
# 1                 54493    Petrol       Manual     Second    24.7 kmpl
# 2                 34000    Diesel       Manual      First   13.68 kmpl
# 3                139000    Diesel       Manual      First   23.59 kmpl
# 4                 29000    Petrol       Manual      First    18.5 kmpl
# ...                 ...       ...          ...        ...          ...
# 1229              89411    Diesel       Manual      First   20.54 kmpl
# 1230              59000    Petrol    Automatic      First   17.21 kmpl
# 1231              28000    Diesel       Manual      First   23.08 kmpl
# 1232              52262    Petrol    Automatic      Third    17.2 kmpl
# 1233              72443    Diesel    Automatic      First    10.0 kmpl
#
#        Engine      Power  Seats
# 0      998 CC   58.2 bhp    4.0
# 1      796 CC   47.3 bhp    5.0
# 2     2393 CC  147.8 bhp    7.0
# 3     1364 CC   null bhp    5.0
# 4     1197 CC  82.85 bhp    5.0
# ...       ...        ...    ...
# 1229  1598 CC  103.6 bhp    5.0
# 1230  1197 CC  103.6 bhp    5.0
# 1231  1461 CC   63.1 bhp    5.0
# 1232  1197 CC  103.6 bhp    5.0
# 1233  2148 CC    170 bhp    5.0
#
# [1234 rows x 11 columns]

# %%
data = data.dropna(how='any')
test = test.dropna(how='any')

# %%
data.shape
# Out:
# (5975, 12)

# %%
test.shape
# Out:
# (1223, 11)

# %%
listtrain = data['Name']
listtest = test['Name']
  
# prints the missing in listrain 
print("Missing values in first list:", (set(listtest).difference(listtrain)))
# Out:
# Missing values in first list: {'OpelCorsa 1.4Gsi', 'Volkswagen Vento 1.5 TDI Highline Plus AT', 'Honda Accord 2001-2003 2.3 VTI L MT', 'Fiat Abarth 595 Competizione', 'Hyundai i20 2015-2017 1.4 CRDi Sportz', 'Tata Tigor 1.2 Revotron XZ Option', 'Mahindra Scorpio VLS 2.2 mHawk', 'Mercedes-Benz B Class B180 Sport', 'Ford Classic 1.4 Duratorq CLXI', 'Hyundai Creta 1.6 VTVT Base', 'Mercedes-Benz B Class B180 Sports', 'Ford Fiesta Classic 1.6 SXI Duratec', 'Hyundai Tucson 2.0 e-VGT 4WD AT GLS', 'Fiat Grande Punto 1.2 Emotion', 'BMW 7 Series 730Ld DPE Signature', 'Maruti Versa DX2', 'Ford Fiesta 1.4 SXI Duratorq', 'Hyundai Santro LS zipDrive Euro I', 'Land Rover Range Rover HSE', 'Mercedes-Benz E-Class 250 D W 124', 'Mahindra KUV 100 mFALCON D75 K6 5str AW', 'Maruti Wagon R VXI AMT Opt', 'Honda City ZX VTEC Plus', 'Tata Indica Vista Terra Quadrajet 1.3L BS IV', 'Maruti Swift VVT ZXI', 'Honda Amaze E i-DTEC', 'Hyundai Creta 1.6 SX Diesel', 'Chevrolet Sail Hatchback 1.2', 'Jeep Compass 1.4 Sport', 'Hyundai EON 1.0 Kappa Magna Plus', 'Mahindra Scorpio S10 8 Seater', 'Nissan Terrano XE 85 PS', 'Land Rover Discovery 4 TDV6 Auto Diesel', 'BMW 7 Series 740i Sedan', 'Hyundai Accent GLX', 'Mitsubishi Pajero Sport 4X2 AT', 'Honda Jazz VX CVT', 'Maruti Ciaz VXi', 'Hyundai i20 Active SX Diesel', 'Toyota Innova Crysta Touring Sport 2.4 MT', 'Maruti Ritz VDi ABS', 'Toyota Innova 2.5 GX 8 STR', 'Nissan Micra XL CVT', 'Maruti A-Star Zxi', 'Maruti Vitara Brezza ZDi AMT', 'Audi Q3 30 TDI S Edition', 'Volkswagen Vento 1.6 Trendline', 'Honda CR-V Diesel', 'Nissan Teana XL', 'Fiat Punto EVO 1.3 Emotion', 'Nissan 370Z AT', 'Mahindra Xylo E9', 'Land Rover Discovery 4 SDV6 SE', 'Hyundai i20 2015-2017 Magna Optional 1.4 CRDi', 'Skoda Laura L and K MT', 'Fiat Linea Classic 1.3 Multijet', 'Mahindra Scorpio VLX 2WD BSIII', 'Mahindra Scorpio VLX Special Edition BS-IV', 'Skoda Rapid Ultima 1.6 TDI Ambition Plus', 'Toyota Land Cruiser Prado VX L', 'Ford Endeavour 3.0L AT 4x2', 'Mercedes-Benz GLA Class 220 d 4MATIC', 'Hyundai Elantra GT', 'Renault Koleos 4X2 MT', 'Honda Civic 2010-2013 1.8 S MT Inspire', 'Fiat Avventura FIRE Dynamic', 'Ford Freestyle Titanium Plus Diesel', 'Ford Fiesta Classic 1.6 Duratec LXI', 'Honda Civic 2010-2013 1.8 V AT', 'Hyundai Sonata Embera 2.4L MT', 'Hyundai EON 1.0 Era Plus', 'Volkswagen Polo ALLSTAR 1.2 MPI', 'Renault Lodgy 110PS RxL', 'Maruti Swift AMT ZXI', 'Honda BR-V i-DTEC S MT', 'Hyundai Creta 1.6 SX Automatic', 'Maruti 800 DX', 'Tata Indica Vista Terra 1.2 Safire BS IV', 'Mahindra Verito Vibe 1.5 dCi D6', 'Volkswagen Jetta 2007-2011 1.6 Trendline', 'Mahindra Bolero SLX', 'Honda Amaze VX CVT i-VTEC', 'Hyundai Santro Xing GLS CNG', 'Hyundai Accent Executive LPG', 'Fiat Linea Dynamic', 'Maruti Vitara Brezza ZDi Plus AMT', 'Mercedes-Benz S Class 2005 2013 320 L', 'Mahindra KUV 100 mFALCON D75 K2', 'Toyota Innova 2.0 V', 'Honda BR-V i-VTEC VX MT', 'Mahindra Xylo H9', 'Ford Ikon 1.4 ZXi', 'Tata Sumo EX 10/7 Str BSII', 'Volkswagen CrossPolo 1.2 TDI', 'Toyota Etios Liva VD', 'Renault Duster 85PS Diesel RxZ', 'BMW 5 Series 530i Sport Line', 'BMW 3 Series GT 320d Sport Line', 'Chevrolet Enjoy Petrol LTZ 7 Seater', 'Audi Q5 2008-2012 3.0 TDI Quattro', 'Toyota Etios Liva 1.4 VXD', 'Maruti Celerio X VXI Option', 'Toyota Camry MT with Moonroof', 'Maruti Ertiga VXI Petrol', 'Hyundai Santro Xing XG AT eRLX Euro III', 'Tata Tiago AMT 1.2 Revotron XTA', 'Hyundai Verna Transform SX VGT CRDi BS III', 'Chevrolet Enjoy TCDi LS 7 Seater', 'Tata Indica Vista Quadrajet LX', 'Ford EcoSport 1.5 Petrol Ambiente', 'Maruti Ciaz VDi Option SHVS', 'Renault Pulse RxZ', 'Hyundai Verna 1.4 CX', 'Mahindra KUV 100 G80 K4 Plus 5Str', 'Toyota Etios Cross 1.2L G', 'Maruti Ignis 1.2 AMT Delta', 'Hindustan Motors Contessa 2.0 DSL', 'Mercedes-Benz CLA 45 AMG', 'Maruti Alto XCITE', 'Mahindra Thar 4X4', 'Hyundai i20 1.4 Asta AT (O) with Sunroof', 'Tata Tiago 1.05 Revotorq XT Option', 'Skoda Laura 1.9 TDI MT Elegance', 'Chevrolet Enjoy 1.4 LTZ 8', 'Hyundai Elite i20 Magna  ...

# %%
data['Cars'] = data['Name'].str.split(" ").str[0] + ' ' +data['Name'].str.split(" ").str[1]
test['Cars'] = test['Name'].str.split(" ").str[0] + ' ' +test['Name'].str.split(" ").str[1]
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_6084\3555247777.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Cars'] = data['Name'].str.split(" ").str[0] + ' ' +data['Name'].str.split(" ").str[1]
# C:\Users\admin\AppData\Local\Temp\ipykernel_6084\3555247777.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Cars'] = test['Name'].str.split(" ").str[0] + ' ' +test['Name'].str.split(" ").str[1]

# %%
set(test['Cars']).issubset(set(data['Cars']))
# Out:
# False

# %%
listtrain = data['Cars']
listtest = test['Cars']
  
# prints the missing and additional elements in list1 
print("Missing values in first list:", (set(listtest).difference(listtrain)))
# Out:
# Missing values in first list: {'Nissan 370Z', 'OpelCorsa 1.4Gsi', 'Isuzu MU', 'Bentley Flying', 'Toyota Land', 'Fiat Abarth', 'Hindustan Motors'}

# %%
test.drop(test[test['Cars'].isin(['Toyota Land', 'Hindustan Motors', 'Fiat Abarth', 'Nissan 370Z', 
                                  'Isuzu MU', 'Bentley Flying', 'OpelCorsa 1.4Gsi'])].index, inplace = True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_6084\1018714766.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.drop(test[test['Cars'].isin(['Toyota Land', 'Hindustan Motors', 'Fiat Abarth', 'Nissan 370Z',

# %%
test.shape
# Out:
# (1216, 12)

# %%
listtrain = data['Cars']
listtest = test['Cars']
  
# prints the missing and additional elements in list1 
print("Missing values in first list:", (set(listtest).difference(listtrain)))
# Out:
# Missing values in first list: set()

# %%
data.head(5)
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price           Cars
# 0   1.75   Maruti Wagon
# 1  12.50  Hyundai Creta
# 2   4.50     Honda Jazz
# 3   6.00  Maruti Ertiga
# 4  17.74        Audi A4

# %%
data['Mileage'] = data['Mileage'].str.replace(' kmpl','')
data['Mileage'] = data['Mileage'].str.replace(' km/kg','')
data['Engine'] = data['Engine'].str.replace(' CC','')
data['Power'] = data['Power'].str.replace('null bhp','112')
data['Power'] = data['Power'].str.replace(' bhp','')

test['Mileage'] = test['Mileage'].str.replace(' kmpl','')
test['Mileage'] = test['Mileage'].str.replace(' km/kg','')
test['Engine'] = test['Engine'].str.replace(' CC','')
test['Power'] = test['Power'].str.replace('null bhp','112')
test['Power'] = test['Power'].str.replace(' bhp','')
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_6084\3829519788.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Mileage'] = data['Mileage'].str.replace(' kmpl','')
# C:\Users\admin\AppData\Local\Temp\ipykernel_6084\3829519788.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Mileage'] = data['Mileage'].str.replace(' km/kg','')
# C:\Users\admin\AppData\Local\Temp\ipykernel_6084\3829519788.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Engine'] = data['Engine'].str.replace(' CC','')
# C:\Users\admin\AppData\Local\Temp\ipykernel_6084\3829519788.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Power'] = data['Power'].str.replace('null bhp','112')
# C:\Users\admin\AppData\Local\Temp\ipykernel_6084\3829519788.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Power'] = data['Power'].str.replace(' bhp','')
# C:\Users\admin\AppData\Local\Temp\ipykernel_6084\3829519788.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Mileage'] = test['Mileage'].str.replace(' kmpl','')
# C:\Users\admin\AppData\Local\Temp\ipykernel_6084\3829519788.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Mileage'] = test['Mileage'].str.replace(' km/kg','')
# C:\Users\admin\AppData\Local\Temp\ipykernel_6084\3829519788.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Engine'] = test['Engine'].str.replace(' CC','')
# C:\Users\admin\AppData\Local\Temp\ipykernel_6084\3829519788.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Power'] = test['Power'].str.replace('null bhp','112')
# C:\Users\admin\AppData\Local\Temp\ipykernel_6084\3829519788.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Power'] = test['Power'].str.replace(' bhp','')

# %%
data.isnull().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# Cars                 0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Cars                 0
# dtype: int64

# %%
data.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# Price                float64
# Cars                  object
# dtype: object

# %%
data.describe()
# Out:
#               Year  Kilometers_Driven        Seats        Price
# count  5975.000000       5.975000e+03  5975.000000  5975.000000
# mean   2013.386778       5.867431e+04     5.278828     9.501647
# std       3.247238       9.155851e+04     0.808959    11.205736
# min    1998.000000       1.710000e+02     0.000000     0.440000
# 25%    2012.000000       3.390800e+04     5.000000     3.500000
# 50%    2014.000000       5.300000e+04     5.000000     5.650000
# 75%    2016.000000       7.300000e+04     5.000000     9.950000
# max    2019.000000       6.500000e+06    10.000000   160.000000

# %%
feature = ['Cars', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission', 
           'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats','Price']
data = pd.DataFrame(data, columns=feature)

feature1 = ['Cars', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission', 
            'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats']
test = pd.DataFrame(test, columns=feature1)

# %%
import copy
df_train=copy.deepcopy(data)
df_test=copy.deepcopy(test)

# %%
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict

# %%
# Assuming 'df_train' and 'df_test' are your DataFrames
categorical_cols = df_train.select_dtypes(include=['object']).columns.tolist()

# %%
categorical_cols = df_train.select_dtypes(include=['object']).columns.tolist()

# Create a dictionary to store encoders for each categorical column
encoder_dict = {}

for col in categorical_cols:
    # Instantiate a LabelEncoder for each column
    encoder = LabelEncoder()
    
    # Fit on the training data
    encoder.fit(df_train[col])
    
    # Transform both training and test data
    df_train[col] = encoder.transform(df_train[col])
    df_test[col] = df_test[col].apply(lambda x: encoder.transform([x])[0] if x in encoder.classes_ else -1)
    
    # Store the encoder in the dictionary
    encoder_dict[col] = encoder

# %%
df_train
# Out:
#       Cars  Location  Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 0      124         9  2010              72000          0             1
# 1       65        10  2015              41000          1             1
# 2       60         2  2011              46000          3             1
# 3      112         2  2012              87000          1             1
# 4        2         3  2013              40670          1             0
# ...    ...       ...   ...                ...        ...           ...
# 6014   121         4  2014              27365          1             1
# 6015    76         6  2015             100000          1             1
# 6016   102         6  2012              55000          1             1
# 6017   124         8  2013              46000          3             1
# 6018    23         5  2011              47000          1             1
#
#       Owner_Type  Mileage  Engine  Power  Seats  Price
# 0              0      391     143    259    5.0   1.75
# 1              0      268      39     56    5.0  12.50
# 2              0      226      12    343    5.0   4.50
# 3              0      300      14    345    7.0   6.00
# 4              2      132      58     76    5.0  17.74
# ...          ...      ...     ...    ...    ...    ...
# 6014           0      401      14    298    5.0   4.75
# 6015           0      366       3    289    5.0   4.00
# 6016           2       90      93     30    8.0   2.90
# 6017           0      247     143    281    5.0   2.65
# 6018           0      379     139    258    5.0   2.50
#
# [5975 rows x 12 columns]

# %%
df_test
# Out:
#       Cars  Location  Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 0      106         4  2014              40929          0             1
# 1      106         3  2013              54493          3             1
# 2      197         9  2017              34000          1             1
# 3      195         5  2012             139000          1             1
# 4       78         9  2014              29000          3             1
# ...    ...       ...   ...                ...        ...           ...
# 1229   207         5  2011              89411          1             1
# 1230   205         9  2015              59000          3             0
# 1231   154         8  2012              28000          1             1
# 1232   205        10  2013              52262          3             0
# 1233   131         7  2014              72443          1             0
#
#       Owner_Type  Mileage  Engine  Power  Seats
# 0              0      404     143    260    4.0
# 1              2      370     136    240    5.0
# 2              0       84      83     85    7.0
# 3              0      356      19     30    5.0
# 4              0      235      10    320    5.0
# ...          ...      ...     ...    ...    ...
# 1229           0      291      46     13    5.0
# 1230           0      194      10     13    5.0
# 1231           0      348      29    267    5.0
# 1232           3      193      10     13    5.0
# 1233           0        1      72    119    5.0
#
# [1216 rows x 11 columns]

# %%
#Train Test Split

# %%
X = df_train.drop(columns=["Price"])  
y = df_train["Price"]  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
ftrain = ['Cars', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission', 
          'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats','Price']

def Definedata():
    # define dataset
    data2 = df_train[ftrain]
    X = data2.drop(columns=['Price']).values
    y0 = data2['Price'].values
    lab_enc = preprocessing.LabelEncoder()
    y = lab_enc.fit_transform(y0)
    return X, y

# %%
from sklearn.ensemble import GradientBoostingRegressor,AdaBoostRegressor,BaggingRegressor, RandomForestRegressor

# %%
Acc = pd.DataFrame(index=None, columns=['model','Root Mean Squared  Error','Accuracy on Traing set','Accuracy on Testing set'])

# %%
X, y = Definedata()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 25)
    
regressors = [['DecisionTreeRegressor',DecisionTreeRegressor()],
              ['XGBRegressor', XGBRegressor()],
              ['RandomForestRegressor', RandomForestRegressor()],
              ['MLPRegressor',MLPRegressor()],
              ['AdaBoostRegressor',AdaBoostRegressor()],
              ['ExtraTreesRegressor',ExtraTreesRegressor()]]

for mod in regressors:
    name = mod[0]
    model = mod[1]
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    
    RMSE = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
    ATrS =  model.score(X_train,y_train)
    ATeS = model.score(X_test,y_test)
    
    Acc = Acc.append(pd.Series({'model':name, 'Root Mean Squared  Error': RMSE,'Accuracy on Traing set':ATrS,'Accuracy on Testing set':ATeS}),ignore_index=True )
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_6084\2668011190.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Acc = Acc.append(pd.Series({'model':name, 'Root Mean Squared  Error': RMSE,'Accuracy on Traing set':ATrS,'Accuracy on Testing set':ATeS}),ignore_index=True )
# C:\Users\admin\AppData\Local\Temp\ipykernel_6084\2668011190.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Acc = Acc.append(pd.Series({'model':name, 'Root Mean Squared  Error': RMSE,'Accuracy on Traing set':ATrS,'Accuracy on Testing set':ATeS}),ignore_index=True )
# C:\Users\admin\AppData\Local\Temp\ipykernel_6084\2668011190.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Acc = Acc.append(pd.Series({'model':name, 'Root Mean Squared  Error': RMSE,'Accuracy on Traing set':ATrS,'Accuracy on Testing set':ATeS}),ignore_index=True )
# C:\Users\admin\AppData\Local\Temp\ipykernel_6084\2668011190.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Acc = Acc.append(pd.Series({'model':name, 'Root Mean Squared  Error': RMSE,'Accuracy on Traing set':ATrS,'Accuracy on Testing set':ATeS}),ignore_index=True )
# C:\Users\admin\AppData\Local\Temp\ipykernel_6084\2668011190.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Acc = Acc.append(pd.Series({'model':name, 'Root Mean Squared  Error': RMSE,'Accuracy on Traing set':ATrS,'Accuracy on Testing set':ATeS}),ignore_index=True )
# C:\Users\admin\AppData\Local\Temp\ipykernel_6084\2668011190.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Acc = Acc.append(pd.Series({'model':name, 'Root Mean Squared  Error': RMSE,'Accuracy on Traing set':ATrS,'Accuracy on Testing set':ATeS}),ignore_index=True )

# %%
Acc.sort_values(by='Accuracy on Testing set')
# Out:
#                    model Root Mean Squared  Error Accuracy on Traing set  \
# 3           MLPRegressor               294.173171                 0.3808
# 4      AdaBoostRegressor                155.46615               0.816789
# 0  DecisionTreeRegressor               123.217755               0.999993
# 2  RandomForestRegressor                84.962695               0.991279
# 5    ExtraTreesRegressor                81.761443               0.999993
# 1           XGBRegressor                74.833829               0.994346
#
#   Accuracy on Testing set
# 3                0.279333
# 4                 0.79872
# 0                0.873563
# 2                0.939885
# 5                0.944329
# 1                0.953364
